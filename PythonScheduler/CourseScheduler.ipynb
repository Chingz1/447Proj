# %% [markdown]
# If you don't have constraint and pandas use 'pip install python-constraint' and 'pip install pandas' in your python terminal and if you dont have jupyter notebooks the code should copy pastr

# %%
from constraint import *
import pandas as pd

class Course(object):
    
    def __init__(self,subject,course,title,ver,sec,professor,time,cap):
        self.subject = subject
        self.course = course
        self.title = title
        self.ver = ver
        self.sec = sec
        self.professor = professor
        self.time = time
        self.cap = cap
        
    def __repr__(self):
        return self.subject + str(self.course)

class Room:
    def __init__(self,name,cap):
        self.name = name
        self.cap = cap
        
    def __repr__(self):
        return self.name
    

file = "ClassRoom.xlsx"
dataClasses = pd.read_excel(file,sheet_name ='Schedule' ) #reading file
dataRooms = pd.read_excel(file,sheet_name ='Capacity' ) #reading file

courses = dataClasses.values
rooms = dataRooms.values
courseList = []
roomList = []

for i in courses:
    courseList.append(Course(i[0],i[1],i[2],i[3],i[4],i[5],i[6],i[7]))
    
for i in rooms:
    roomList.append(Room(i[0],i[1]))

    

#create Dict
database = {'courses': courseList, 'rooms': roomList}

problem = Problem()

for key, value in database.items():
    problem.addVariable(key, value)

def cap_constraint(Course,Room):
    if(Course.cap <= Room.cap):
        return True
    
    
problem.addConstraint(cap_constraint,['courses','rooms'])



# Get solutions
solutions = problem.getSolutions()
print(len(solutions))
print(*solutions, sep = "\n")
# Out:
# 719
# {'rooms': Sherman Hall 151, 'courses': CMSC447}
# {'rooms': Sherman Hall 151, 'courses': CMSC447}
# {'rooms': Sherman Hall 151, 'courses': CMSC447}
# {'rooms': Sherman Hall 151, 'courses': CMSC447}
# {'rooms': Sherman Hall 151, 'courses': CMSC 291}
# {'rooms': Sherman Hall 013, 'courses': CMSC684}
# {'rooms': Sherman Hall 013, 'courses': CMSC491}
# {'rooms': Sherman Hall 013, 'courses': CMSC461}
# {'rooms': Sherman Hall 013, 'courses': CMSC461}
# {'rooms': Sherman Hall 013, 'courses': CMSC455}
# {'rooms': Sherman Hall 013, 'courses': CMSC441}
# {'rooms': Sherman Hall 013, 'courses': CMSC441}
# {'rooms': Sherman Hall 013, 'courses': CMSC441}
# {'rooms': Sherman Hall 013, 'courses': CMSC426}
# {'rooms': Sherman Hall 013, 'courses': CMSC426}
# {'rooms': Sherman Hall 013, 'courses': CMSC421}
# {'rooms': Sherman Hall 013, 'courses': CMSC421}
# {'rooms': Sherman Hall 013, 'courses': CMSC421}
# {'rooms': Sherman Hall 013, 'courses': CMSC411cs}
# {'rooms': Sherman Hall 013, 'courses': CMSC411cs}
# {'rooms': Sherman Hall 013, 'courses': CMSC411cs}
# {'rooms': Sherman Hall 013, 'courses': CMSC411ce}
# {'rooms': Sherman Hall 013, 'courses': CMSC341}
# {'rooms': Sherman Hall 013, 'courses': CMSC341}
# {'rooms': Sherman Hall 013, 'courses': CMSC341}
# {'rooms': Sherman Hall 013, 'courses': CMSC341}
# {'rooms': Sherman Hall 013, 'courses': CMSC341}
# {'rooms': Sherman Hall 013, 'courses': CMSC341}
# {'rooms': Sherman Hall 013, 'courses': CMSC331}
# {'rooms': Sherman Hall 013, 'courses': CMSC331}
# {'rooms': Sherman Hall 013, 'courses': CMSC331}
# {'rooms': Sherman Hall 013, 'courses': CMSC331}
# {'rooms': Sherman Hall 013, 'courses': CMSC313}
# {'rooms': Sherman Hall 013, 'courses': CMSC313}
# {'rooms': Sherman Hall 013, 'courses': CMSC313}
# {'rooms': Sherman Hall 013, 'courses': CMSC313}
# {'rooms': Sherman Hall 013, 'courses': CMSC304}
# {'rooms': Sherman Hall 013, 'courses': CMSC304}
# {'rooms': Sherman Hall 013, 'courses': CMSC304}
# {'rooms': Sherman Hall 013, 'courses': CMSC304}
# {'rooms': Sherman Hall 013, 'courses': CMSC304}
# {'rooms': Sherman Hall 013, 'courses': CMSC304}
# {'rooms': Sherman Hall 013, 'courses': CMSC203}
# {'rooms': Sherman Hall 013, 'courses': CMSC203}
# {'rooms': Sherman Hall 013, 'courses': CMSC203}
# {'rooms': Sherman Hall 013, 'courses': CMSC203}
# {'rooms': Sherman Hall 013, 'courses': CMSC203}
# {'rooms': Sherman Hall 013, 'courses': CMSC104}
# {'rooms': Sherman Hall 013, 'courses': CMSC104}
# {'rooms': Sherman Hall 013, 'courses': CMSC447}
# {'rooms': Sherman Hall 013, 'courses': CMSC447}
# {'rooms': Sherman Hall 013, 'courses': CMSC447}
# {'rooms': Sherman Hall 013, 'courses': CMSC447}
# {'rooms': Sherman Hall 013, 'courses': CMSC 291}
# {'rooms': Math & Psychology 106, 'courses': CMSC684}
# {'rooms': Math & Psychology 106, 'courses': CMSC491}
# {'rooms': Math & Psychology 106, 'courses': CMSC461}
# {'rooms': Math & Psychology 106, 'courses': CMSC461}
# {'rooms': Math & Psychology 106, 'courses': CMSC455}
# {'rooms': Math & Psychology 106, 'courses': CMSC441}
# {'rooms': Math & Psychology 106, 'courses': CMSC441}
# {'rooms': Math & Psychology 106, 'courses': CMSC441}
# {'rooms': Math & Psychology 106, 'courses': CMSC426}
# {'rooms': Math & Psychology 106, 'courses': CMSC426}
# {'rooms': Math & Psychology 106, 'courses': CMSC421}
# {'rooms': Math & Psychology 106, 'courses': CMSC421}
# {'rooms': Math & Psychology 106, 'courses': CMSC421}
# {'rooms': Math & Psychology 106, 'courses': CMSC411cs}
# {'rooms': Math & Psychology 106, 'courses': CMSC411cs}
# {'rooms': Math & Psychology 106, 'courses': CMSC411cs}
# {'rooms': Math & Psychology 106, 'courses': CMSC411ce}
# {'rooms': Math & Psychology 106, 'courses': CMSC341}
# {'rooms': Math & Psychology 106, 'courses': CMSC341}
# {'rooms': Math & Psychology 106, 'courses': CMSC341}
# {'rooms': Math & Psychology 106, 'courses': CMSC341}
# {'rooms': Math & Psychology 106, 'courses': CMSC341}
# {'rooms': Math & Psychology 106, 'courses': CMSC341}
# {'rooms': Math & Psychology 106, 'courses': CMSC331}
# {'rooms': Math & Psychology 106, 'courses': CMSC331}
# {'rooms': Math & Psychology 106, 'courses': CMSC331}
# {'rooms': Math & Psychology 106, 'courses': CMSC331}
# {'rooms': Math & Psychology 106, 'courses': CMSC313}
# {'rooms': Math & Psychology 106, 'courses': CMSC313}
# {'rooms': Math & Psychology 106, 'courses': CMSC313}
# {'rooms': Math & Psychology 106, 'courses': CMSC313}
# {'rooms': Math & Psychology 106, 'courses': CMSC304}
# {'rooms': Math & Psychology 106, 'courses': CMSC304}
# {'rooms': Math & Psychology 106, 'courses': CMSC304}
# {'rooms': Math & Psychology 106, 'courses': CMSC304}
# {'rooms': Math & Psychology 106, 'courses': CMSC304}
# {'rooms': Math & Psychology 106, 'courses': CMSC304}
# {'rooms': Math & Psychology 106, 'courses': CMSC203}
# {'rooms': Math & Psychology 106, 'courses': CMSC203}
# {'rooms': Math & Psychology 106, 'courses': CMSC203}
# {'rooms': Math & Psychology 106, 'courses': CMSC203}
# {'rooms': Math & Psychology 106, 'courses': CMSC203}
# {'rooms': Math & Psychology 106, 'courses': CMSC104}
# {'rooms': Math & Psychology 106, 'courses': CMSC104}
# {'rooms': Math & Psychology 106, 'courses': CMSC447}
# {'rooms': Math & Psychology 106, 'courses': CMSC447}
# {'rooms': Math & Psychology 106, 'courses': CMSC447}
# {'rooms': Math & Psychology 106, 'courses': CMSC447}
# {'rooms': Math & Psychology 106, 'courses': CMSC 291}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC684}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC491}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC461}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC461}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC455}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC441}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC441}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC441}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC426}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC426}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC421}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC421}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC421}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC411cs}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC411cs}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC411cs}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC411ce}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC331}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC331}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC331}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC331}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC313}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC313}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC313}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC313}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC104}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC104}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC447}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC447}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC447}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC447}
# {'rooms': Interdisciplinary Life S 233, 'courses': CMSC 291}
# {'rooms': Biological Sciences 120, 'courses': CMSC684}
# {'rooms': Biological Sciences 120, 'courses': CMSC491}
# {'rooms': Biological Sciences 120, 'courses': CMSC461}
# {'rooms': Biological Sciences 120, 'courses': CMSC461}
# {'rooms': Biological Sciences 120, 'courses': CMSC455}
# {'rooms': Biological Sciences 120, 'courses': CMSC441}
# {'rooms': Biological Sciences 120, 'courses': CMSC441}
# {'rooms': Biological Sciences 120, 'courses': CMSC441}
# {'rooms': Biological Sciences 120, 'courses': CMSC426}
# {'rooms': Biological Sciences 120, 'courses': CMSC426}
# {'rooms': Biological Sciences 120, 'courses': CMSC421}
# {'rooms': Biological Sciences 120, 'courses': CMSC421}
# {'rooms': Biological Sciences 120, 'courses': CMSC421}
# {'rooms': Biological Sciences 120, 'courses': CMSC411cs}
# {'rooms': Biological Sciences 120, 'courses': CMSC411cs}
# {'rooms': Biological Sciences 120, 'courses': CMSC411cs}
# {'rooms': Biological Sciences 120, 'courses': CMSC411ce}
# {'rooms': Biological Sciences 120, 'courses': CMSC341}
# {'rooms': Biological Sciences 120, 'courses': CMSC341}
# {'rooms': Biological Sciences 120, 'courses': CMSC341}
# {'rooms': Biological Sciences 120, 'courses': CMSC341}
# {'rooms': Biological Sciences 120, 'courses': CMSC341}
# {'rooms': Biological Sciences 120, 'courses': CMSC341}
# {'rooms': Biological Sciences 120, 'courses': CMSC331}
# {'rooms': Biological Sciences 120, 'courses': CMSC331}
# {'rooms': Biological Sciences 120, 'courses': CMSC331}
# {'rooms': Biological Sciences 120, 'courses': CMSC331}
# {'rooms': Biological Sciences 120, 'courses': CMSC313}
# {'rooms': Biological Sciences 120, 'courses': CMSC313}
# {'rooms': Biological Sciences 120, 'courses': CMSC313}
# {'rooms': Biological Sciences 120, 'courses': CMSC313}
# {'rooms': Biological Sciences 120, 'courses': CMSC304}
# {'rooms': Biological Sciences 120, 'courses': CMSC304}
# {'rooms': Biological Sciences 120, 'courses': CMSC304}
# {'rooms': Biological Sciences 120, 'courses': CMSC304}
# {'rooms': Biological Sciences 120, 'courses': CMSC304}
# {'rooms': Biological Sciences 120, 'courses': CMSC304}
# {'rooms': Biological Sciences 120, 'courses': CMSC203}
# {'rooms': Biological Sciences 120, 'courses': CMSC203}
# {'rooms': Biological Sciences 120, 'courses': CMSC203}
# {'rooms': Biological Sciences 120, 'courses': CMSC203}
# {'rooms': Biological Sciences 120, 'courses': CMSC203}
# {'rooms': Biological Sciences 120, 'courses': CMSC104}
# {'rooms': Biological Sciences 120, 'courses': CMSC104}
# {'rooms': Biological Sciences 120, 'courses': CMSC447}
# {'rooms': Biological Sciences 120, 'courses': CMSC447}
# {'rooms': Biological Sciences 120, 'courses': CMSC447}
# {'rooms': Biological Sciences 120, 'courses': CMSC447}
# {'rooms': Biological Sciences 120, 'courses': CMSC 291}
# {'rooms': Sherman Hall 014, 'courses': CMSC491/691}
# {'rooms': Sherman Hall 014, 'courses': CMSC691}
# {'rooms': Sherman Hall 014, 'courses': CMSC682}
# {'rooms': Sherman Hall 014, 'courses': CMSC678}
# {'rooms': Sherman Hall 014, 'courses': CMSC641}
# {'rooms': Sherman Hall 014, 'courses': CMSC621}
# {'rooms': Sherman Hall 014, 'courses': CMSC611}
# {'rooms': Sherman Hall 014, 'courses': CMSC493}
# {'rooms': Sherman Hall 014, 'courses': CMSC491/691}
# {'rooms': Sherman Hall 014, 'courses': CMSC491/691}
# {'rooms': Sherman Hall 014, 'courses': CMSC487/687}
# {'rooms': Sherman Hall 014, 'courses': CMSC483/691}
# {'rooms': Sherman Hall 014, 'courses': CMSC691}
# {'rooms': Sherman Hall 014, 'courses': CMSC481}
# {'rooms': Sherman Hall 014, 'courses': CMSC479/679}
# {'rooms': Sherman Hall 014, 'courses': CMSC478}
# {'rooms': Sherman Hall 014, 'courses': CMSC476/676}
# {'rooms': Sherman Hall 014, 'courses': CMSC471}
# {'rooms': Sherman Hall 014, 'courses': CMSC471}
# {'rooms': Sherman Hall 014, 'courses': CMSC471}
# {'rooms': Sherman Hall 014, 'courses': CMSC443/652}
# {'rooms': Sherman Hall 014, 'courses': CMSC435/634}
# {'rooms': Sherman Hall 014, 'courses': CMSC684}
# {'rooms': Sherman Hall 014, 'courses': CMSC491}
# {'rooms': Sherman Hall 014, 'courses': CMSC461}
# {'rooms': Sherman Hall 014, 'courses': CMSC461}
# {'rooms': Sherman Hall 014, 'courses': CMSC455}
# {'rooms': Sherman Hall 014, 'courses': CMSC441}
# {'rooms': Sherman Hall 014, 'courses': CMSC441}
# {'rooms': Sherman Hall 014, 'courses': CMSC441}
# {'rooms': Sherman Hall 014, 'courses': CMSC426}
# {'rooms': Sherman Hall 014, 'courses': CMSC426}
# {'rooms': Sherman Hall 014, 'courses': CMSC421}
# {'rooms': Sherman Hall 014, 'courses': CMSC421}
# {'rooms': Sherman Hall 014, 'courses': CMSC421}
# {'rooms': Sherman Hall 014, 'courses': CMSC411cs}
# {'rooms': Sherman Hall 014, 'courses': CMSC411cs}
# {'rooms': Sherman Hall 014, 'courses': CMSC411cs}
# {'rooms': Sherman Hall 014, 'courses': CMSC411ce}
# {'rooms': Sherman Hall 014, 'courses': CMSC341}
# {'rooms': Sherman Hall 014, 'courses': CMSC341}
# {'rooms': Sherman Hall 014, 'courses': CMSC341}
# {'rooms': Sherman Hall 014, 'courses': CMSC341}
# {'rooms': Sherman Hall 014, 'courses': CMSC341}
# {'rooms': Sherman Hall 014, 'courses': CMSC341}
# {'rooms': Sherman Hall 014, 'courses': CMSC331}
# {'rooms': Sherman Hall 014, 'courses': CMSC331}
# {'rooms': Sherman Hall 014, 'courses': CMSC331}
# {'rooms': Sherman Hall 014, 'courses': CMSC331}
# {'rooms': Sherman Hall 014, 'courses': CMSC313}
# {'rooms': Sherman Hall 014, 'courses': CMSC313}
# {'rooms': Sherman Hall 014, 'courses': CMSC313}
# {'rooms': Sherman Hall 014, 'courses': CMSC313}
# {'rooms': Sherman Hall 014, 'courses': CMSC304}
# {'rooms': Sherman Hall 014, 'courses': CMSC304}
# {'rooms': Sherman Hall 014, 'courses': CMSC304}
# {'rooms': Sherman Hall 014, 'courses': CMSC304}
# {'rooms': Sherman Hall 014, 'courses': CMSC304}
# {'rooms': Sherman Hall 014, 'courses': CMSC304}
# {'rooms': Sherman Hall 014, 'courses': CMSC203}
# {'rooms': Sherman Hall 014, 'courses': CMSC203}
# {'rooms': Sherman Hall 014, 'courses': CMSC203}
# {'rooms': Sherman Hall 014, 'courses': CMSC203}
# {'rooms': Sherman Hall 014, 'courses': CMSC203}
# {'rooms': Sherman Hall 014, 'courses': CMSC104}
# {'rooms': Sherman Hall 014, 'courses': CMSC104}
# {'rooms': Sherman Hall 014, 'courses': CMSC447}
# {'rooms': Sherman Hall 014, 'courses': CMSC447}
# {'rooms': Sherman Hall 014, 'courses': CMSC447}
# {'rooms': Sherman Hall 014, 'courses': CMSC447}
# {'rooms': Sherman Hall 014, 'courses': CMSC 291}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC491/691}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC691}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC682}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC678}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC641}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC621}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC611}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC493}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC491/691}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC491/691}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC487/687}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC483/691}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC691}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC481}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC479/679}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC478}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC476/676}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC471}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC471}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC471}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC443/652}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC435/634}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC684}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC491}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC461}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC461}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC455}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC441}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC441}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC441}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC426}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC426}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC421}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC421}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC421}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC411cs}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC411cs}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC411cs}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC411ce}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC341}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC341}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC341}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC341}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC341}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC341}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC331}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC331}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC331}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC331}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC313}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC313}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC313}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC313}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC304}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC304}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC304}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC304}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC304}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC304}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC203}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC203}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC203}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC203}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC203}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC104}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC104}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC447}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC447}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC447}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC447}
# {'rooms': Meyerhoff Chemistry 030, 'courses': CMSC 291}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC491/691}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC691}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC682}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC678}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC641}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC621}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC611}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC493}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC491/691}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC491/691}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC487/687}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC483/691}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC691}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC481}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC479/679}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC478}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC476/676}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC471}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC471}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC471}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC443/652}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC435/634}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC684}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC491}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC461}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC461}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC455}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC441}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC441}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC441}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC426}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC426}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC421}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC421}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC421}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC411cs}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC411cs}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC411cs}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC411ce}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC341}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC341}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC341}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC341}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC341}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC341}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC331}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC331}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC331}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC331}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC313}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC313}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC313}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC313}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC304}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC304}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC304}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC304}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC304}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC304}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC203}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC203}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC203}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC203}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC203}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC104}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC104}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC447}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC447}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC447}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC447}
# {'rooms': Janet & Walter Sondheim 109, 'courses': CMSC 291}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC201ss}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC491/691}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC691}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC682}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC678}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC641}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC621}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC611}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC493}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC491/691}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC491/691}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC487/687}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC483/691}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC691}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC481}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC479/679}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC478}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC476/676}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC471}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC471}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC471}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC443/652}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC435/634}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC684}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC491}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC461}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC461}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC455}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC441}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC441}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC441}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC426}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC426}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC421}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC421}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC421}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC411cs}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC411cs}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC411cs}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC411ce}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC341}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC331}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC331}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC331}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC331}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC313}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC313}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC313}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC313}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC304}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC203}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC104}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC104}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC447}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC447}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC447}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC447}
# {'rooms': Interdisciplinary Life S 237, 'courses': CMSC 291}
# {'rooms': Information Technology 227, 'courses': CMSC201ss}
# {'rooms': Information Technology 227, 'courses': CMSC491/691}
# {'rooms': Information Technology 227, 'courses': CMSC691}
# {'rooms': Information Technology 227, 'courses': CMSC682}
# {'rooms': Information Technology 227, 'courses': CMSC678}
# {'rooms': Information Technology 227, 'courses': CMSC641}
# {'rooms': Information Technology 227, 'courses': CMSC621}
# {'rooms': Information Technology 227, 'courses': CMSC611}
# {'rooms': Information Technology 227, 'courses': CMSC493}
# {'rooms': Information Technology 227, 'courses': CMSC491/691}
# {'rooms': Information Technology 227, 'courses': CMSC491/691}
# {'rooms': Information Technology 227, 'courses': CMSC487/687}
# {'rooms': Information Technology 227, 'courses': CMSC483/691}
# {'rooms': Information Technology 227, 'courses': CMSC691}
# {'rooms': Information Technology 227, 'courses': CMSC481}
# {'rooms': Information Technology 227, 'courses': CMSC479/679}
# {'rooms': Information Technology 227, 'courses': CMSC478}
# {'rooms': Information Technology 227, 'courses': CMSC476/676}
# {'rooms': Information Technology 227, 'courses': CMSC471}
# {'rooms': Information Technology 227, 'courses': CMSC471}
# {'rooms': Information Technology 227, 'courses': CMSC471}
# {'rooms': Information Technology 227, 'courses': CMSC443/652}
# {'rooms': Information Technology 227, 'courses': CMSC435/634}
# {'rooms': Information Technology 227, 'courses': CMSC684}
# {'rooms': Information Technology 227, 'courses': CMSC491}
# {'rooms': Information Technology 227, 'courses': CMSC461}
# {'rooms': Information Technology 227, 'courses': CMSC461}
# {'rooms': Information Technology 227, 'courses': CMSC455}
# {'rooms': Information Technology 227, 'courses': CMSC441}
# {'rooms': Information Technology 227, 'courses': CMSC441}
# {'rooms': Information Technology 227, 'courses': CMSC441}
# {'rooms': Information Technology 227, 'courses': CMSC426}
# {'rooms': Information Technology 227, 'courses': CMSC426}
# {'rooms': Information Technology 227, 'courses': CMSC421}
# {'rooms': Information Technology 227, 'courses': CMSC421}
# {'rooms': Information Technology 227, 'courses': CMSC421}
# {'rooms': Information Technology 227, 'courses': CMSC411cs}
# {'rooms': Information Technology 227, 'courses': CMSC411cs}
# {'rooms': Information Technology 227, 'courses': CMSC411cs}
# {'rooms': Information Technology 227, 'courses': CMSC411ce}
# {'rooms': Information Technology 227, 'courses': CMSC341}
# {'rooms': Information Technology 227, 'courses': CMSC341}
# {'rooms': Information Technology 227, 'courses': CMSC341}
# {'rooms': Information Technology 227, 'courses': CMSC341}
# {'rooms': Information Technology 227, 'courses': CMSC341}
# {'rooms': Information Technology 227, 'courses': CMSC341}
# {'rooms': Information Technology 227, 'courses': CMSC331}
# {'rooms': Information Technology 227, 'courses': CMSC331}
# {'rooms': Information Technology 227, 'courses': CMSC331}
# {'rooms': Information Technology 227, 'courses': CMSC331}
# {'rooms': Information Technology 227, 'courses': CMSC313}
# {'rooms': Information Technology 227, 'courses': CMSC313}
# {'rooms': Information Technology 227, 'courses': CMSC313}
# {'rooms': Information Technology 227, 'courses': CMSC313}
# {'rooms': Information Technology 227, 'courses': CMSC304}
# {'rooms': Information Technology 227, 'courses': CMSC304}
# {'rooms': Information Technology 227, 'courses': CMSC304}
# {'rooms': Information Technology 227, 'courses': CMSC304}
# {'rooms': Information Technology 227, 'courses': CMSC304}
# {'rooms': Information Technology 227, 'courses': CMSC304}
# {'rooms': Information Technology 227, 'courses': CMSC203}
# {'rooms': Information Technology 227, 'courses': CMSC203}
# {'rooms': Information Technology 227, 'courses': CMSC203}
# {'rooms': Information Technology 227, 'courses': CMSC203}
# {'rooms': Information Technology 227, 'courses': CMSC203}
# {'rooms': Information Technology 227, 'courses': CMSC104}
# {'rooms': Information Technology 227, 'courses': CMSC104}
# {'rooms': Information Technology 227, 'courses': CMSC447}
# {'rooms': Information Technology 227, 'courses': CMSC447}
# {'rooms': Information Technology 227, 'courses': CMSC447}
# {'rooms': Information Technology 227, 'courses': CMSC447}
# {'rooms': Information Technology 227, 'courses': CMSC 291}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC203}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC202}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC202}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC202}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC202}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC202}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC201}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC201}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC201ss}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC491/691}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC691}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC682}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC678}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC641}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC621}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC611}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC493}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC491/691}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC491/691}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC487/687}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC483/691}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC691}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC481}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC479/679}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC478}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC476/676}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC471}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC471}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC471}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC443/652}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC435/634}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC684}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC491}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC461}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC461}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC455}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC441}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC441}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC441}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC426}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC426}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC421}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC421}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC421}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC411cs}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC411cs}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC411cs}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC411ce}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC341}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC341}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC341}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC341}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC341}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC341}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC331}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC331}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC331}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC331}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC313}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC313}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC313}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC313}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC304}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC304}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC304}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC304}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC304}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC304}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC203}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC203}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC203}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC203}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC203}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC104}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC104}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC447}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC447}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC447}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC447}
# {'rooms': Engineering 122, Engineering 122A, 'courses': CMSC 291}
# {'rooms': Public Policy 105, 'courses': CMSC201}
# {'rooms': Public Policy 105, 'courses': CMSC203}
# {'rooms': Public Policy 105, 'courses': CMSC202}
# {'rooms': Public Policy 105, 'courses': CMSC202}
# {'rooms': Public Policy 105, 'courses': CMSC202}
# {'rooms': Public Policy 105, 'courses': CMSC202}
# {'rooms': Public Policy 105, 'courses': CMSC202}
# {'rooms': Public Policy 105, 'courses': CMSC201}
# {'rooms': Public Policy 105, 'courses': CMSC201}
# {'rooms': Public Policy 105, 'courses': CMSC201ss}
# {'rooms': Public Policy 105, 'courses': CMSC491/691}
# {'rooms': Public Policy 105, 'courses': CMSC691}
# {'rooms': Public Policy 105, 'courses': CMSC682}
# {'rooms': Public Policy 105, 'courses': CMSC678}
# {'rooms': Public Policy 105, 'courses': CMSC641}
# {'rooms': Public Policy 105, 'courses': CMSC621}
# {'rooms': Public Policy 105, 'courses': CMSC611}
# {'rooms': Public Policy 105, 'courses': CMSC493}
# {'rooms': Public Policy 105, 'courses': CMSC491/691}
# {'rooms': Public Policy 105, 'courses': CMSC491/691}
# {'rooms': Public Policy 105, 'courses': CMSC487/687}
# {'rooms': Public Policy 105, 'courses': CMSC483/691}
# {'rooms': Public Policy 105, 'courses': CMSC691}
# {'rooms': Public Policy 105, 'courses': CMSC481}
# {'rooms': Public Policy 105, 'courses': CMSC479/679}
# {'rooms': Public Policy 105, 'courses': CMSC478}
# {'rooms': Public Policy 105, 'courses': CMSC476/676}
# {'rooms': Public Policy 105, 'courses': CMSC471}
# {'rooms': Public Policy 105, 'courses': CMSC471}
# {'rooms': Public Policy 105, 'courses': CMSC471}
# {'rooms': Public Policy 105, 'courses': CMSC443/652}
# {'rooms': Public Policy 105, 'courses': CMSC435/634}
# {'rooms': Public Policy 105, 'courses': CMSC684}
# {'rooms': Public Policy 105, 'courses': CMSC491}
# {'rooms': Public Policy 105, 'courses': CMSC461}
# {'rooms': Public Policy 105, 'courses': CMSC461}
# {'rooms': Public Policy 105, 'courses': CMSC455}
# {'rooms': Public Policy 105, 'courses': CMSC441}
# {'rooms': Public Policy 105, 'courses': CMSC441}
# {'rooms': Public Policy 105, 'courses': CMSC441}
# {'rooms': Public Policy 105, 'courses': CMSC426}
# {'rooms': Public Policy 105, 'courses': CMSC426}
# {'rooms': Public Policy 105, 'courses': CMSC421}
# {'rooms': Public Policy 105, 'courses': CMSC421}
# {'rooms': Public Policy 105, 'courses': CMSC421}
# {'rooms': Public Policy 105, 'courses': CMSC411cs}
# {'rooms': Public Policy 105, 'courses': CMSC411cs}
# {'rooms': Public Policy 105, 'courses': CMSC411cs}
# {'rooms': Public Policy 105, 'courses': CMSC411ce}
# {'rooms': Public Policy 105, 'courses': CMSC341}
# {'rooms': Public Policy 105, 'courses': CMSC341}
# {'rooms': Public Policy 105, 'courses': CMSC341}
# {'rooms': Public Policy 105, 'courses': CMSC341}
# {'rooms': Public Policy 105, 'courses': CMSC341}
# {'rooms': Public Policy 105, 'courses': CMSC341}
# {'rooms': Public Policy 105, 'courses': CMSC331}
# {'rooms': Public Policy 105, 'courses': CMSC331}
# {'rooms': Public Policy 105, 'courses': CMSC331}
# {'rooms': Public Policy 105, 'courses': CMSC331}
# {'rooms': Public Policy 105, 'courses': CMSC313}
# {'rooms': Public Policy 105, 'courses': CMSC313}
# {'rooms': Public Policy 105, 'courses': CMSC313}
# {'rooms': Public Policy 105, 'courses': CMSC313}
# {'rooms': Public Policy 105, 'courses': CMSC304}
# {'rooms': Public Policy 105, 'courses': CMSC304}
# {'rooms': Public Policy 105, 'courses': CMSC304}
# {'rooms': Public Policy 105, 'courses': CMSC304}
# {'rooms': Public Policy 105, 'courses': CMSC304}
# {'rooms': Public Policy 105, 'courses': CMSC304}
# {'rooms': Public Policy 105, 'courses': CMSC203}
# {'rooms': Public Policy 105, 'courses': CMSC203}
# {'rooms': Public Policy 105, 'courses': CMSC203}
# {'rooms': Public Policy 105, 'courses': CMSC203}
# {'rooms': Public Policy 105, 'courses': CMSC203}
# {'rooms': Public Policy 105, 'courses': CMSC104}
# {'rooms': Public Policy 105, 'courses': CMSC104}
# {'rooms': Public Policy 105, 'courses': CMSC447}
# {'rooms': Public Policy 105, 'courses': CMSC447}
# {'rooms': Public Policy 105, 'courses': CMSC447}
# {'rooms': Public Policy 105, 'courses': CMSC447}
# {'rooms': Public Policy 105, 'courses': CMSC 291}
