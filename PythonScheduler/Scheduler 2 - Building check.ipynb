# %% [markdown]
# monday/wednesday: 10, 1, 230,4, 530, 710
# tuesday/thursday: 10, 1130, 1, 230, 4, 530, 710
# monday/wednesday/friday: 10

# %%
import pandas as pd
from pandas import *
import tabulate #pip install tabulate
class Course(object):
    
    shed = False
    
    
    def __init__(self,subject,course,title,ver,sec,professor,time,cap):
        self.subject = subject
        self.course = course
        self.title = title
        self.ver = ver
        self.sec = sec
        self.professor = professor
        self.time = time
        self.cap = cap
        
    def __repr__(self):
        return self.subject + " " + str(self.course) + " " + self.professor + " " + self.time

class Room(object):
    taken = False
    
    def __init__(self,name,cap):
        self.name = name
        self.cap = cap
        
    def __repr__(self):
        return self.name

class Schedule(object):
    
    mw =[]
    tt =[]
    mwf = []
    
    solution = [[],[],[],[],[]]
    

file = "ClassRoom.xlsx"
dataClasses = pd.read_excel(file,sheet_name ='Schedule' ) #reading file
dataRooms = pd.read_excel(file,sheet_name ='Capacity' ) #reading file

courses = dataClasses.values
rooms = dataRooms.values

courseList = []
roomList = []

spring2020 = Schedule()



for i in dataClasses.Time:
    if("mw" in i ) and not(i in spring2020.mw):
        spring2020.mw.append(i)
    if("tt" in i ) and not(i in spring2020.tt):
        spring2020.tt.append(i)
    if("MWF" in i ) and not(i in spring2020.mwf):
        spring2020.mwf.append(i)
        
        
for i in courses:
    courseList.append(Course(i[0],i[1],i[2],i[3],i[4],i[5],i[6],i[7]))
    
for i in rooms:
    roomList.append(Room(i[0],i[1]))
    
    
for i in spring2020.mw:
    for j in courseList:
        if (j.time == i) or ("MWF" in j.time):
            for k in roomList:
                 if(j.cap  <= k.cap) and not(k.taken) and not(j.shed):
                    j.shed = True
                    k.taken = True
                    spring2020.solution[0].append({j:k})
                    spring2020.solution[2].append({j:k})
                    if("MWF" in j .time):
                        spring2020.solution[4].append({j:k})
    for t in roomList:
        t.taken = False
            
            
for i in spring2020.tt:
    for j in courseList:
        if j.time == i:
            for k in roomList:
                 if(j.cap  <= k.cap) and not(k.taken) and not(j.shed):
                    j.shed = True
                    k.taken = True
                    spring2020.solution[1].append({j:k})
                    spring2020.solution[3].append({j:k})
    for t in roomList:
        t.taken = False
        


    
                                
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]

for i in range(len(spring2020.solution)):
    header = spring2020.solution[0][i].values()
    rows = [x.keys() for x in spring2020.solution[i]]
    print( tabulate.tabulate(rows, header))
    print("\n")
    
# for i in range(len(spring2020.solution)):
#     print(days[i])
#     for j in spring2020.solution[i]:
#         print(j)
        

print("Unscheduled:")
for i in courseList:
    if(not(i.shed)):
        print(i)
# Out:
# Public Policy 105
# ---------------------------------
# CMSC 104 Staff mw530
# CMSC 202 Joeg, Prasanna mw530
# CMSC 203 Hamilton, Eric mw530
# CMSC 304 Staff mw530
# CMSC 304 Staff mw530
# CMSC 421 Staff mw530
# CMSC 471 Staff mw530
# CMSC 201ss Staff mw230
# CMSC 203 Joeg, Prasanna mw230
# CMSC 313 Sekyonda, Ivan mw230
# CMSC 341 Bargteil, Adam mw230
# CMSC 411cs Olano, Marc mw230
# CMSC 447 Dutt, Abhijit mw230
# CMSC 461 Staff mw230
# CMSC 201 Hamilton, Eric mw1
# CMSC 202 Dixon, Jeremy mw1
# CMSC 203 Joeg, Prasanna mw1
# CMSC 313 Kartchner, Jeannette mw1
# CMSC 331 Donyaee, Kash mw1
# CMSC 341 Johnson, Benjamin mw1
# CMSC 411cs Sekyonda, Ivan mw1
# CMSC 447 Dutt, Abhijit mw1
# CMSC 201 Hamilton, Eric mw4
# CMSC 341 Johnson, Benjamin mw4
# CMSC 455 Squire, Jon mw4
# CMSC 471 Vafaei, Fereydoon mw4
# CMSC 491 Dutt, Abhijit mw4
# CMSC 641 Sherman, Alan MWF10
# CMSC 691 Ferraro, Frank mw4
# CMSC  291 Staff mw10
# CMSC 341 Marron, Christopher mw10
# CMSC 441 Marron, Christopher mw10
# CMSC 304 Staff mw710
#
#
# Interdisciplinary Life S 237
# ------------------------------------
# CMSC 104 Staff tt530
# CMSC 203 Wilson, Marcella tt530
# CMSC 304 Staff tt530
# CMSC 304 Staff tt530
# CMSC 411cs Staff tt530
# CMSC 447 Staff tt530
# CMSC 483/691 Simon, Tyler tt530
# CMSC 201 Johnson, Benjamin tt1130
# CMSC 203 Yesha, Yaacov tt1130
# CMSC 313 Sekyonda, Ivan tt1130
# CMSC 421 Staff tt1130
# CMSC 461 Kalpakis, Kostas tt1130
# CMSC 478 Vafaei, Fereydoon tt1130
# CMSC 202 Dixon, Jeremy tt10
# CMSC 203 Yesha, Yaacov tt10
# CMSC 331 Donyaee, Kash tt10
# CMSC 441 Chang, Richard tt10
# CMSC 443/652 Zhang, Haibin tt10
# CMSC 202 Donyaee, Kash tt230
# CMSC 341 Wilson, Marcella tt230
# CMSC 411ce Squire, Jon tt230
# CMSC 421 Perkins, Dmitri tt230
# CMSC 479/679 Matuszek, Cynthia tt230
# CMSC 678 Oates, Tim tt230
# CMSC 202 Donyaee, Kash tt4
# CMSC 313 Sekyonda, Ivan tt4
# CMSC 331 Vafaei, Fereydoon tt4
# CMSC 426 Staff tt4
# CMSC 471 Finin, Tim tt4
# CMSC 481 Sidhu, Deepinder tt4
# CMSC 491/691 Chapman, David tt4
# CMSC 304 Staff tt710
# CMSC 447 Staff tt710
# CMSC 691 Sidhu, Deepinder tt710
# CMSC 487/687 Zieglar, Edward tt710
# CMSC 331 Vafaei, Fereydoon tt1
# CMSC 341 Wilson, Marcella tt1
# CMSC 426 Staff tt1
# CMSC 441 Chang, Richard tt1
# CMSC 493 staff tt1
# CMSC 621 Kalpakis, Kostas tt1
#
#
# Janet & Walter Sondheim 109
# -----------------------------
# CMSC 641 Sherman, Alan MWF10
#
#
# Unscheduled:
# CMSC 435/634 Olano, Marc mw1
# CMSC 476/676 Pearce, Claudia mw1
# CMSC 491/691 Nicholas, Charles mw530
# CMSC 611 Liu, Chenchen tt4
# CMSC 682 Sidhu, Deepinder tt530
# CMSC 684 Younis, Mohamed MW230
# CMSC 491/691 Zhu, Ting mw1

# %% [markdown]
# monday/wednesday: 10, 1, 230,4, 530, 710
# tuesday/thursday: 10, 1130, 1, 230, 4, 530, 710
# monday/wednesday/friday: 10
#
# 37/
